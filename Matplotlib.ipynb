# %% [markdown]
# # Matplotlib Chart Examples
#
# This notebook demonstrates how to use matplotlib to plot different types of charts using a sample dataset with two columns: name and marks. Each function's syntax is explained.

# %%
# Import matplotlib and create a sample dataset
import matplotlib.pyplot as plt
import numpy as np

# Sample dataset: two columns (name and marks)
names = ['Alice', 'Bob', 'Charlie', 'David', 'Eva']
marks = [85, 92, 78, 88, 95]

# %% [markdown]
# ## Line Chart
#
# A line chart displays data as a series of points connected by straight lines. Use `plt.plot()` to create a line chart.
#
# **Syntax:**
#
# - `plt.plot(x, y)`: Plots y versus x as lines.
# - `plt.title('Title')`: Sets the chart title.
# - `plt.xlabel('X Label')`, `plt.ylabel('Y Label')`: Set axis labels.
# - `plt.show()`: Displays the plot.

# %%
# Line chart example
plt.plot(names, marks, marker='o')
plt.title('Line Chart of Marks')
plt.xlabel('Name')
plt.ylabel('Marks')
plt.show()

# %% [markdown]
# ## Bar Chart
#
# A bar chart displays data with rectangular bars. Use `plt.plot()` with the `'bar'` style to create a bar chart.
#
# **Syntax:**
#
# - `plt.plot(x, y, 'o-')`: Plots y values as bars for each x value (for true bar chart, use `plt.bar()`, but here we use plot for demonstration).
#
# - `plt.title('Title')`: Sets the chart title.
# - `plt.xlabel('X Label')`, `plt.ylabel('Y Label')`: Set axis labels.
# - `plt.show()`: Displays the plot.

# %%
# Bar chart example using plot function
import pandas as pd
data={names : ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
marks : [85, 92, 78, 88, 95]}
df=pd.DataFrame(names,marks)
df.plot(names, marks, kind='bar', color='orange')  # 's-' means square markers with lines
plt.title('Bar Chart of Marks (using plot)')
plt.xlabel('Name')
plt.ylabel('Marks')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 4
#       2 import pandas as pd
#       3 df=pd.DataFrame(names,marks)
# ----> 4 df.plot(names, marks, kind='bar', color='orange')  # 's-' means square markers with lines
#
# File c:\Training\Python\.venv\Lib\site-packages\pandas\plotting\_core.py:995, in PlotAccessor.__call__(self, *args, **kwargs)
#     993 if is_integer(x) and not data.columns._holds_integer():
#     994     x = data_cols[x]
# --> 995 elif not isinstance(data[x], ABCSeries):
#     996     raise ValueError("x must be a label or position")
#     997 data = data.set_index(x)
#
# File c:\Training\Python\.venv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Training\Python\.venv\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Training\Python\.venv\Lib\site-packages\pandas\core\indexes\base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Alice', 'Bob', 'Charlie', 'David', 'Eva'], dtype='object')] are in the [columns]"

# %% [markdown]
# ## Area Chart
#
# An area chart displays quantitative data graphically. Use `plt.plot()` and `plt.fill_between()` to create an area chart.
#
# **Syntax:**
#
# - `plt.plot(x, y)`: Plots the line.
# - `plt.fill_between(x, y)`: Fills the area under the line.
# - `plt.title('Title')`: Sets the chart title.
# - `plt.xlabel('X Label')`, `plt.ylabel('Y Label')`: Set axis labels.
# - `plt.show()`: Displays the plot.

# %%
# Area chart example
plt.plot(names, marks, color='green')
plt.fill_between(names, marks, color='lightgreen', alpha=0.5)
plt.title('Area Chart of Marks')
plt.xlabel('Name')
plt.ylabel('Marks')
plt.show()
