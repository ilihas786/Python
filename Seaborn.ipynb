# %% [markdown]
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for creating attractive and informative statistical graphics, such as bar plots, box plots, heatmaps, and more. Seaborn makes it easy to visualize complex datasets and supports integration with pandas DataFrames for quick plotting.

# %%
import seaborn as sns
df=sns.load_dataset("iris")

# %% [markdown]
# ## KDE Plot
#
# A KDE (Kernel Density Estimate) plot is a way to visualize the probability density of a continuous variable. It smooths the data using a kernel function, providing a continuous curve that represents the distribution. KDE plots are useful for understanding the underlying distribution of data, especially compared to histograms.
#
# **Syntax:**
# - `sns.kdeplot(data, x='column_name')`: Plots the KDE for the specified column in the data.

# %%
# Example: KDE plot of the 'sepal_width' column in the iris dataset
import matplotlib.pyplot as plt
sns.kdeplot(data=df, x='sepal_width', fill=True)
plt.title('KDE Plot of Sepal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ## Dist Plot
#
# A dist plot (distribution plot) in seaborn visualizes the distribution of a numeric variable. It combines a histogram (showing frequency) and a KDE curve (showing probability density). This helps you understand the shape, spread, and central tendency of your data.
#
# **Syntax:**
# - `sns.histplot(data, x='column_name', kde=True)`: Plots a histogram and KDE for the specified column.

# %%
# Example: Dist plot of the 'sepal_width' column in the iris dataset
sns.histplot(data=df, x='sepal_width', kde=True)
plt.title('Dist Plot of Sepal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Frequency')
plt.show()
